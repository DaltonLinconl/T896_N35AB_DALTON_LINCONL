# %% [markdown]
# # Chroma Key
#
# Neste projeto, será aplicado uma técnica de Chroma Key para substituir o fundo verde de uma
# imagem por um novo cenário. Duas imagens serão fornecidas: uma com uma ou mais pessoas sobre
# fundo verde e outra com o novo fundo (background). O objetivo é criar um script em Python,
# utilizando OpenCV, que isole a pessoa e insira corretamente o novo plano de fundo

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
# Carrega a imagem
img_cinza1 = cv2.imread("projeto_1/img_fundo_verde_1.jpg")
img_rgb = cv2.cvtColor(img_cinza1, cv2.COLOR_BGR2RGB)

plt.imshow(img_rgb)
plt.axis('off')  # opcional: remove os eixos
plt.show()

# %%
# Resultado
plt.figure(figsize=(12, 4))

plt.subplot(1, 3, 1)
plt.imshow(img_cinza1_RGB)
plt.title("img_cinza1_RGB")
plt.axis("off")


plt.subplot(1, 3, 2)
plt.imshow(img_cinza2_RGB)
plt.title("img_cinza2_RGB")
plt.axis("off")

plt.subplot(1, 3, 3)
plt.imshow(img_cinza3_RGB)
plt.title("img_cinza3_RGB")
plt.axis("off")


plt.show()
